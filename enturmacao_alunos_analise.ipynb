# %%
import numpy as np
import pandas as pd

from itertools import repeat, chain
from collections import Counter

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="white", palette=None)

# %% [markdown]
# # Análise dos dados

# %%
df = pd.read_csv('alunos.csv')
df.head()
# Out:
#        Nome PrimeiraLetra  Procedencia Sexo  Idade
# 0  JOAQUIM              J          368    M     11
# 1  MATHEUS              M          368    M     11
# 2    BENTO              B          368    M     12
# 3  TEODORA              T          368    F     11
# 4  LORENZO              L          368    M     11

# %% [markdown]
# ## Análise gráfica dos atributos

# %%
df.PrimeiraLetra.value_counts()
plt.figure(figsize=(12, 6))
plt.xlabel('Primeira Letra', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
ax=sns.countplot(data=df, x='PrimeiraLetra')
for container in ax.containers:
    ax.bar_label(container)
plt.tight_layout()

# %%
plt.figure(figsize=(8, 6))
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
ax=sns.countplot(data=df, x='Sexo')
for container in ax.containers:
    ax.bar_label(container)
plt.tight_layout()

# %%
plt.figure(figsize=(8, 6))
plt.xlabel('Idade', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
ax=sns.countplot(data=df, x='Idade')
for container in ax.containers:
    ax.bar_label(container)
plt.tight_layout()

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('Procedencia', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
ax=sns.countplot(data=df, x='Procedencia')
for container in ax.containers:
    ax.bar_label(container)
plt.tight_layout()
